# %%
import json
import pandas as pd

# %%
with open('D:\Projects\data analytics\data\jsonRequest.json') as f:
    data = json.load(f)
    canibalizacion=data["canibalizacion"]
    periodo=data["Periodo"]
    pais=data["Pais"]
    data_ofertas=data["ProductosOfertas"]
    
                         
    
    
    
print(data_ofertas)
# Out:
# [{'COD_PERIODO': '202305', 'ID_COMPONENTE': 10892858, 'COD_PAIS': 'CL', 'ALCANCE': 'MASIVO', 'COD_CATALOGO': '24', 'ID_TIPO_SUBESTRATEGIA': 999, 'ID_OFERTA': 7401927, 'ID_GRUPO': 8662167, 'ES_GRUPO_PADRE': 1, 'ID_SUB_GRUPO': 8662167, 'ID_TIPO_GRUPO': 3, 'ID_TIPO_SUB_GRUPO': 3, 'COD_CUC': '200091759', 'COD_SAP': '200091759', 'DESUNIDADNEGOCIO': 'COSMETICOS', 'DESMARCA': 'LBEL', 'DESCLASE': 'FRAGANCIAS', 'DESCATEGORIA': 'FRAGANCIAS', 'DESTIPOSOLO': 'COLONIA Y O EAU DE TOILETE', 'PRECIO_NORMAL': 42900.0, 'PRECIO_OFERTA': 9624.0, 'FACTOR_CUADRE': 1, 'FACTOR_REPETICION': 2, 'TARGET': 'CONSULTORA', 'ES_PADRE': 0, 'DESEXPOSICION': 'MENOS DE 1/8 PAGINA 6.25%', 'DESTIPOCATALOGO': None, 'DESUBICACIONCATALOGO': 'OTROS / CUALQUIER PAGINA', 'FLAGBULK': 0, 'FLAGDISCOVER': 0, 'FLAGFOTOPRODUCTO': 1, 'FLAGFOTOMODELO': 0, 'NROPAGINAS': 2, 'CICLO_DE_VIDA': 'Linea', 'N_CAMPAIGN': 36, 'FLAG_RXP': 0, 'NUM_PAGINA': 25, 'CODIGO_FRANJA': None, 'EXPOSICION': 6.25}, {'COD_PERIODO': '202305', 'ID_COMPONENTE': 1
# ...
